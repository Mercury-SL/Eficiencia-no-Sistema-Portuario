# %% [markdown]
# <a href="https://colab.research.google.com/github/Mercury-SL/Eficiencia-no-Sistema-Portuario/blob/main/Carga_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bibliotecas iniciais
# !pip install pandas
import io

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from google.colab import drive
drive.mount('/content/drive')

path_in = '/content/drive/My Drive/Data/'
path_out = '/content/drive/My Drive/Data/'

file1 = path_in + '2014Carga.csv'
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file2 = path_in + '2015Carga.csv'
df2 = pd.read_csv(file2, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file3= path_in + '2016Carga.csv'
df3 = pd.read_csv(file3, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file4 = path_in + '2017Carga.csv'
df4 = pd.read_csv(file4, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file5 = path_in + '2018Carga.csv'
df5 = pd.read_csv(file5, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file6 = path_in + '2019Carga.csv'
df6 = pd.read_csv(file6, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file7 = path_in + '2020Carga.csv'
df7 = pd.read_csv(file7, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file8 = path_in + '2021Carga.csv'
df8 = pd.read_csv(file8, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file9 = path_in + '2022Carga.csv'
df9 = pd.read_csv(file9, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file10 = path_in + '2023Carga.csv'
df10 = pd.read_csv(file10, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

csv_final = [file1, file2, file3, file4, file5, file6, file7, file8, file9, file10]
ANTAQ_Int = pd.DataFrame()
for csv_final in csv_final:
    df = pd.read_csv(csv_final, sep = ';')
    ANTAQ_Int = pd.concat([ANTAQ_Int, df], ignore_index=True)
ANTAQ_Int.info()

ANTAQ_Int.head(5)

duplicados = ANTAQ_Int.duplicated(subset=['IDAtracacao'], keep=False)
if duplicados.any():
    print("Existem valores duplicados.")
    print(ANTAQ_Int[duplicados])
else:
    print("Coluna com valores unicos.")

colunas_interesse1 = ['IDCarga','IDAtracacao', 'Origem',
                     'Destino', 'CDMercadoria',
                     'STSH2', 'STSH4', 'QTCarga', 'VLPesoCargaBruta']
ANTAQ_Int[colunas_interesse1].to_csv(path_out + 'Carga_final.csv', index=False)

drive.mount('/content/drive')
arquivo = '/content/drive/My Drive/Data/Carga_final.csv'
with open(arquivo, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")

df = pd.read_csv(arquivo, low_memory=False, sep=',', encoding='UTF-8')
df.head()
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-3-34b9555bf488>:49: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# Streaming output truncated to the last 5000 lines.
# 433276  0.0      0.0
# 433277  0.0      0.0
# 433278  0.0      0.0
# 433279  0.0      0.0
# 433280  0.0      0.0
# 433281  0.0      0.0
# 433282  0.0      0.0
# 433284  0.0      0.0
# 433285  0.0      0.0
# 433286  0.0      0.0
# 433287  0.0      0.0
# 433288  0.0      0.0
# 433289  0.0      0.0
# 433290  0.0      0.0
# 433291  0.0      0.0
# 433292  0.0      0.0
# 433293  0.0      0.0
# 433294  0.0      0.0
# 433295  0.0      0.0
# 433317  0.0      0.0
# 433318  0.0      0.0
# 433319  0.0      0.0
# 433320  0.0      0.0
# 433321  0.0      0.0
# 433322  0.0      0.0
# 433323  0.0      0.0
# 433324  0.0      0.0
# ...
